# %% [markdown]
# <a href="https://colab.research.google.com/github/Lele237/BI/blob/main/fun%C3%A7%C3%B5esepar%C3%A2metros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mangá= {}
mangá= int(input("quantos mangás você quer cadastrar?:"))
print(mangá)
# Out:
# quantos mangás você quer cadastrar?:1
# 1

# %%
def cadastrar_mangá(nome, autor, editora):
  print("nome do mangá:", nome)
  print("autor:", autor)
  print("qual editora publicou?:", editora)
  return cadastrar_mangá

# %%
nome = input("Nome do mangá:")
autor = input("nome do autor:")
editora = input("nome da editora:")

cadastrar_mangá(nome, autor, editora)
# Out:
# Nome do mangá:Tokyo Ghoul
# nome do autor:Sui Ishida
# nome da editora:Panini
# nome do mangá: Tokyo Ghoul
# autor: Sui Ishida
# qual editora publicou?: Panini
# <function __main__.cadastrar_mangá(nome, autor, editora)>

# %%
def calcular_imposto(lista_valores):
  imposto_total=0

  if valor_mangá > 255:
      taxa= 0.90
  else:
    taxa = 0.20

    imposto = valor_mangá * taxa
    imposto_total = imposto_total + imposto

  return imposto_total

# %%
valor_mangá = float(input("Qual o valor do mangá?:"))
print(valor_mangá)

imposto_lista1 = calcular_imposto(valor_mangá)
print("imposto:", imposto_lista1)
# Out:
# Qual o valor do mangá?:15
# 15.0
# imposto: 3.0
