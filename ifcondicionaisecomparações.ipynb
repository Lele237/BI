# %% [markdown]
# <a href="https://colab.research.google.com/github/Lele237/BI/blob/main/ifcondicionaisecompara%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while True:
  bleach_characters= input()
  if bleach_characters.lower() == "sair":
    break
  if bleach_characters.lower() == "aizen":
    print(f"{bleach_characters} I love u")
  elif bleach_characters.lower() == "tousen":
    print("Safe")
  elif bleach_characters.lower() == "gin":
    print("traitor")
  elif bleach_characters.lower() == "ichigo":
    print("BANKAI!")
  else:
    print("Oh, Kyouka Suigetsu")
# Out:
# ichigo
# BANKAI!
# gin
# traitor
# tousen
# Safe
# aizen
# aizen I love u
# sair
