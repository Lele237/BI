# %% [markdown]
# <a href="https://colab.research.google.com/github/Lele237/BI/blob/main/tuplas_e_fun%C3%A7%C3%B5es_multiplas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ast import Break
hd = (1280, 720)
full_hd = (1920, 1080)
ultra_hd = (3840, 2160)

def mostrar_resolução(resolucao):
  largura=resolucao[0]
  altura= resolucao[1]

  return f"resolução: {largura} x {altura}"

opcao = 0

while True:
  print("Escolha a resolução:")
  print("1- hd:")
  print("2- full_hd:")
  print("3- ultra_hd:")
  print("4- sair:")

  opcao= int(input("digite uma opção:"))

  if opcao == 1:
    resultado = hd

  elif opcao == 2:
    resultado = full_hd

  elif opcao == 3:
    resultado = ultra_hd

  elif opcao == 4:
    print("programa encerrado")
    break

  else:
    resultado = "opção inválida!"

print(resultado)
# Out:
# Escolha a resolução:
# 1- hd:
# 2- full_hd:
# 3- ultra_hd:
# 4- sair:
# digite uma opção:1
# Escolha a resolução:
# 1- hd:
# 2- full_hd:
# 3- ultra_hd:
# 4- sair:
# digite uma opção:4
# programa encerrado
# (1280, 720)
