# %% [markdown]
# <a href="https://colab.research.google.com/github/Lele237/BI/blob/main/shinigamis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
character= {}
character= int(input("quantidade de personagensa serem cadastrados"))
print(character)

for i in range(character):
  nome = input("nome do personagem:")
  divisão = input("divisão do personagem:")
  cargo = input("cargo do personagem:")
  ativo = input("status:")

character = {
    "nome" : nome,
    "divisão": divisão,
    "cargo": cargo,
    "ativo": ativo
}

print(character)

# %%
from os import scandir
while True:
  buscar_personagem= input("qual personagem você está procurando:")
  buscar_personagem= buscar_personagem.strip()
  buscar_personagem = buscar_personagem.lower()

  if buscar_personagem == "sair":
    break

  if buscar_personagem == character["nome"]:
    print("encontrado")

  else:
    print("not found")
